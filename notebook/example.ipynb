# %%
import pandas as pd
from ape_risk import strategies

# %%
strat = strategies.gbms(initial_value=1.0, num_points=10000, params=[0, 0.005])

# %%
ex = strat.example()
ex
# Out:
# array([1.00731741, 1.00979248, 1.00184809, ..., 1.45372147, 1.44582943,
#        1.44242582])

# %%
df = pd.DataFrame(ex, columns=['price'])

# %%
df
# Out:
#          price
# 0     1.007317
# 1     1.009792
# 2     1.001848
# 3     1.006861
# 4     1.014965
# ...        ...
# 9995  1.467516
# 9996  1.457733
# 9997  1.453721
# 9998  1.445829
# 9999  1.442426
#
# [10000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
df.to_csv("../tests/helpers/example.csv", index=False)
